# %% [markdown]
# 足し算

# %%
10+2
# Out:
# 12

# %%
111+222
# Out:
# 333

# %% [markdown]
# 引き算

# %%
10-4
# Out:
# 6

# %%
10 - 4
# Out:
# 6

# %%
10-20
# Out:
# -10

# %%
-10+6
# Out:
# -4

# %%
+4-1
# Out:
# 3

# %% [markdown]
# 掛け算

# %%
10*10
# Out:
# 100

# %%
1.08*100
# Out:
# 108.0

# %%
10*10*10
# Out:
# 1000

# %% [markdown]
# 割り算

# %%
1800/100
# Out:
# 18.0

# %%
(100+300)/4
# Out:
# 100.0

# %%
(2+3)*10
# Out:
# 50

# %% [markdown]
# べき乗

# %%
2**3
# Out:
# 8

# %%
2**4
# Out:
# 16

# %% [markdown]
# 複素数

# %%
(4+2j)-(2+1j)
# Out:
# (2+1j)
