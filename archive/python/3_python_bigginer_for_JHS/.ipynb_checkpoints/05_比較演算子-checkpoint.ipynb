# %%
1 < 3
# Out:
# True

# %%
1 > 3
# Out:
# False

# %%
1 > -1
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
1 != 2
# Out:
# True

# %%
2 >= 1
# Out:
# True

# %%
'今西' == '今西'
# Out:
# True

# %%
'今西' == 'Imanishi'
# Out:
# False

# %%
'今西' != 'Imanishi'
# Out:
# True
