# %%
a=120

# %%
type(a)
# Out:
# int

# %% [markdown]
# intとはintegerの略語で整数を表す

# %%
b=4.5

# %%
type(b)
# Out:
# float

# %% [markdown]
# floatとは小数（浮動小数）を表す

# %%
complex = 3j

# %%
type(complex)
# Out:
# complex

# %% [markdown]
# complexとは、複素数を表す

# %%
name = '今西'

# %%
type(name)
# Out:
# str

# %% [markdown]
# strとはstringの略語で文字列を表す

# %%
flg = True

# %%
type(flg)
# Out:
# bool

# %% [markdown]
# boolとはbooleanの略語で論理型（True,False）を表す

# %%
c = [10, 20]

# %%
type(c)
# Out:
# list

# %% [markdown]
# listとはリスト型を表す

# %%
d={}

# %%
type(d)
# Out:
# dict

# %% [markdown]
# dicとはdictionaryの略語で辞書型を表す

# %%
e=()

# %%
type(e)
# Out:
# tuple

# %% [markdown]
# tupleとはタプル型と呼ばれる
