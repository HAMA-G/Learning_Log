# %% [markdown]
# リスト

# %%
names = ['今西', '鈴木', '佐藤']
names
# Out:
# ['今西', '鈴木', '佐藤']

# %%
type(names)
# Out:
# list

# %%
names[0]
# Out:
# '今西'

# %%
names[1]
# Out:
# '鈴木'

# %%
scores = [50, 80, 60]
scores
# Out:
# [50, 80, 60]

# %%
scores[2]
# Out:
# 60

# %%
scores[-1]
# Out:
# 60

# %%
scores[-2]
# Out:
# 80

# %% [markdown]
# 0:2の意味
# 0番目から始まり、2番目の要素の一つ前の値まで取得するという意味

# %%
scores[0:2]
# Out:
# [50, 80]

# %% [markdown]
# 全てを取得する方法

# %%
scores
# Out:
# [50, 80, 60]

# %%
scores[0:]
# Out:
# [50, 80, 60]

# %%
scores[:]
# Out:
# [50, 80, 60]

# %% [markdown]
# リストの最後の一つ手前までを取得

# %%
scores[:-1]
# Out:
# [50, 80]

# %% [markdown]
# リストの追加

# %%
scores.append(70)

# %%
scores
# Out:
# [50, 80, 60, 70]

# %%
scores.append(90)

# %%
scores
# Out:
# [50, 80, 60, 70, 90]

# %% [markdown]
# リストの一部の値を削除する

# %%
scores.pop()
# Out:
# 90

# %%
scores
# Out:
# [50, 80, 60, 70]

# %%
scores.pop(0)
# Out:
# 50

# %%
scores
# Out:
# [80, 60, 70]

# %% [markdown]
# 削除に関する関数を確認する

# %%
clear
remove
del

# %% [markdown]
# 辞書
# {キー:バリュー}

# %%
scores = {'国語':50, '数学':80, '英語':60}

# %%
scores
# Out:
# {'国語': 50, '数学': 80, '英語': 60}

# %%
scores[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 scores[0]
#
# KeyError: 0

# %%
scores['数学']
# Out:
# 80

# %%
scores['国語']
# Out:
# 50

# %%
scores['理科'] = 70

# %%
scores
# Out:
# {'国語': 50, '数学': 80, '英語': 60, '理科': 70}

# %%
scores['社会'] = 100

# %%
scores
# Out:
# {'国語': 50, '数学': 80, '英語': 60, '理科': 70, '社会': 100}

# %% [markdown]
# タプル
# 利点1：使用するメモリが最小
# 利点2：追加や削除ができない
# 中身を変更しない場合はタプルを使用するといい

# %%
scores = (10, 30, 40)

# %%
scores[0]
# Out:
# 10

# %%
scores.append(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 scores.append(50)
#
# AttributeError: 'tuple' object has no attribute 'append'
