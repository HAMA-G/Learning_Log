# %%
money = 1000

# %%
if money >= 2000:
    print('映画館に行きます')

# %%
if money >= 2000:
    print('映画館にいきます')
else:
    print('映画館にはいきません')
# Out:
# 映画館にはいきません

# %%
money = 1000
if money >= 8000:
    print('ディスニーランドに行く')
elif money >= 2000:
    print('映画館に行きます')
else:
    print('どこにもいきません')
# Out:
# どこにもいきません
