# %% [markdown]
# while分とは特定の条件になるまで繰り返し処理を行う

# %%
time = 60

while time > 0:
    print('残り',time, '秒')
    time -= 1

print('試合終了')
# Out:
# 残り 60 秒
# 残り 59 秒
# 残り 58 秒
# 残り 57 秒
# 残り 56 秒
# 残り 55 秒
# 残り 54 秒
# 残り 53 秒
# 残り 52 秒
# 残り 51 秒
# 残り 50 秒
# 残り 49 秒
# 残り 48 秒
# 残り 47 秒
# 残り 46 秒
# 残り 45 秒
# 残り 44 秒
# 残り 43 秒
# 残り 42 秒
# 残り 41 秒
# 残り 40 秒
# 残り 39 秒
# 残り 38 秒
# 残り 37 秒
# 残り 36 秒
# 残り 35 秒
# 残り 34 秒
# 残り 33 秒
# 残り 32 秒
# 残り 31 秒
# 残り 30 秒
# 残り 29 秒
# 残り 28 秒
# 残り 27 秒
# 残り 26 秒
# 残り 25 秒
# 残り 24 秒
# 残り 23 秒
# 残り 22 秒
# 残り 21 秒
# 残り 20 秒
# 残り 19 秒
# 残り 18 秒
# 残り 17 秒
# 残り 16 秒
# 残り 15 秒
# 残り 14 秒
# 残り 13 秒
# 残り 12 秒
# 残り 11 秒
# 残り 10 秒
# 残り 9 秒
# 残り 8 秒
# 残り 7 秒
# 残り 6 秒
# 残り 5 秒
# 残り 4 秒
# 残り 3 秒
# 残り 2 秒
# 残り 1 秒
# 試合終了
