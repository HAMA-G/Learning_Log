# %% [markdown]
# Pythonではパッケージと呼ばれる
# 他の言語ではライブラリと呼ばれることが多い

# %%
import math

# %% [markdown]
# 円周率を示す→mathには他にもたくさんある
# 数学的な計算で使えるものがたくさんあるので、下記のURLより確認するといい
# https://docs.python.org/ja/3.13/library/math.html

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# 日付datetime
# from 〇〇　import △△
# ライブラリ（パッケージ）の中から、指定した機能をインポートするときに用いる

# %%
from datetime import date

# %%
date.today()
# Out:
# datetime.date(2025, 5, 7)

# %%
date.today().year
# Out:
# 2025

# %%
date.today().month
# Out:
# 5

# %%
date.today().day
# Out:
# 7

# %% [markdown]
# ライブラリの活用方法→実現したい機能がライブラリにあるかを確認した上で、ない場合に自分で作成するという流れを使うことが重要
