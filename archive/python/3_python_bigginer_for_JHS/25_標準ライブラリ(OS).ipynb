# %%
import os

# %% [markdown]
# 作業ディレクトリの場所を確認する
# cwd:current work directoryの略

# %%
os.getcwd()
# Out:
# '/Users/hamajikoki/Documents/1_self_study/python/3_python_bigginer_for_JHS'

# %% [markdown]
# Linuxコマンドの実行方法はコマンドの前に「!」をつけると実行できる

# %%
# !pwd
# Out:
# /Users/hamajikoki/Documents/1_self_study/python/3_python_bigginer_for_JHS

# %% [markdown]
# ファイル削除

# %%
os.remove('/Users/hamajikoki/Documents/1_self_study/python/3_python_bigginer_for_JHS/sample_data/README.txt')

# %% [markdown]
# ファイル名変更

# %%
os.rename('/Users/hamajikoki/Documents/1_self_study/python/3_python_bigginer_for_JHS/sample_data/README.md','/Users/hamajikoki/Documents/1_self_study/python/3_python_bigginer_for_JHS/sample_data/LOOKME.md')

# %% [markdown]
# ディレクトリの作成
# mkdir:make directoryの略

# %%
os.mkdir('new_directory')

# %% [markdown]
# ディレクトリの削除
# rmdir:remove directory

# %%
os.rmdir('new_directory')

# %% [markdown]
# ディレクトリ内の確認

# %%
os.listdir('/Users/hamajikoki/Documents/1_self_study/python/3_python_bigginer_for_JHS/sample_data')
# Out:
# ['california_housing_train.csv',
#  'anscombe.json',
#  'california_housing_test.csv',
#  'LOOKME.md',
#  '.ipynb_checkpoints']

# %% [markdown]
# python os
# https://docs.python.org/ja/3.13/library/os.html
