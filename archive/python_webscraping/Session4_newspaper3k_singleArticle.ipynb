# %% [markdown]
# 単一記事の取得

# %%
from newspaper import Article

# %%
URL = "https://www.bloomberg.co.jp/news/articles/2024-06-22/SFGECBT1UM0W00?srnd=cojp-v2"

# %%
article = Article(URL)

# %%
article.download()

# %%
article.parse()

# %%
article.publish_date
# Out:
# datetime.datetime(2024, 6, 22, 0, 0)

# %% [markdown]
# 記事の作成日時の取得

# %%
article.publish_date
# Out:
# datetime.datetime(2024, 6, 22, 0, 0)

# %% [markdown]
# ページの全文の取得→疑問bodyタグ内のテキスト部分を取得？

# %%
article.text
# Out:
# '商品メーカーとして、ウォール街は絶好調だ。高利回りのオプション取引や銀行融資をパッケージ化したファンドなど、投資のプロとしての強みを個人投資家にもたらすと称する戦略の当たり年になりそうだ。\n\n米株式市場の平穏に賭ける取引に巨額資金－2018年の二の舞いはないか\n\n経済や米連邦準備制度の政策に不安を抱える顧客に対し、あらゆる金融会社が独創的な取引を売り込んでいる。しかし事実上、今はＳ＆Ｐ500種株価指数を買い保有するという最もシンプルな資産配分ほど稼げる取引はない。\n\nマネーマネジャーらは、分散投資とされる戦略の数々に資金をつぎ込んできた。だが、上場投資信託（ＥＴＦ）４本につき約３本がＳ＆Ｐ500種に打ち負かされるのを黙って見ているしかなかった。これは少なくとも2010年以来最悪の負け方だ。\n\nミューチュアルファンド運用担当者のお気に入り銘柄は、半年間の成績でそうした運用担当者が最も敬遠している銘柄に大きく後れを取っている。\n\nエバコアＩＳＩの株式・デリバティブ・クオンツ担当チーフストラテジスト、ジュリアン・エマニュエル氏は、「2024年のような低ボラティリティー、高リターンの環境では、投資家は基本に忠実であるべきだ。戦略を複雑にする必要はない。シンプルさには美しさがある」と述べた。\n\n株高の犠牲\n\n最大級の時価総額加重平均型株価指数からあえて外れた投資家は、何度も何度も惨敗した。 エヌビディアやマイクロソフトなどの株価が雪だるま式に上昇し、正しい側に立つ投資家にとっては好材料だ。Ｓ＆Ｐ500種の年初来上昇率はまだ６月だというのに約15％に達している。\n\n集中的な株高の犠牲となったのは分散投資だ。資産クラスとしての債券は依然として値下がり。ブルームバーグ・コモディティー指数で追跡される原材料はわずか３％の上昇にとどまっている。\n\nブルームバーグ・インテリジェンス（ＢＩ）のアタナシオス・プサロファギス氏は、株式ＥＴＦのうちＳ＆Ｐ500種を今年上回ることができているのはわずか約４分の１だと分析している。\n\nアクティブ運用ＥＴＦや クオンツ運用のスマートベータ、テーマ型ＥＴＦなど、パフォーマンスを追い求める戦略は相対パフォーマンスが最も低いＥＴＦの一角だ。\n\nＳ＆Ｐ500種やナスダック100といった株価指数の絶え間ない上昇は
# ...

# %% [markdown]
# 記事のタイトルを取得→疑問：titleタグの情報を取得？

# %%
article.title
# Out:
# 'ウォール街のスマート軍団、株高に打ち負かされる－今こそ警戒か'

# %% [markdown]
# newspaper3kでは自然言語処理でキーワードの取得やサマリーを取得することができる
