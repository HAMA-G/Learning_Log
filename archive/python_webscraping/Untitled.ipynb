# %%
from newspaper import Article

# %%
url = "https://www.japan-it.jp/spring/ja-jp/search/2025/directory.html?locale=ja-JP&query=&refinementList%5B0%5D%5B0%5D=exhibitorFilters.%E8%A3%BD%E5%93%81%2F%E3%82%B5%E3%83%BC%E3%83%93%E3%82%B9.lvl0%3Aid-865207&refinementList%5B0%5D%5B1%5D=sponsoredCategory.id%3A865212&refinementList%5B1%5D%5B0%5D=sponsoredCategory.id%3A865212&refinementList%5B1%5D%5B1%5D=exhibitorFilters.%E8%A3%BD%E5%93%81%2F%E3%82%B5%E3%83%BC%E3%83%93%E3%82%B9.lvl1%3Aid-865212#/"

# %%
article = Article(url, memoize_article = False)

# %%
print(article)

# %%
article.download()

# %%
article.parse()

# %%
print(article.title)
# Out:
# 出展社検索（2025年度 春展）｜Japan IT Week, Japan DX Week, 営業・デジタルマーケティング Week, EC・店舗 Week【春】
