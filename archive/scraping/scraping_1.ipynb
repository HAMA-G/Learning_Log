# %%
import requests

# %%
url = "https://www.jashin.info/kiura/scraping/category/products/"

# %%
res = requests.get(url)

# %%
print(res.status_code)
# Out:
# 200

# %%
print(res.text[:500])
# Out:
# <!DOCTYPE html>
# <html lang="ja">
# <head>
# 	<meta charset="UTF-8" />
# 	<meta name="viewport" content="width=device-width, initial-scale=1" />
# <meta name='robots' content='noindex, nofollow' />
# <title>products &#8211; スクレイピング演習用デモサイト</title>
# <link rel="alternate" type="application/rss+xml" title="スクレイピング演習用デモサイト &raquo; フィード" href="https://www.jashin.info/kiura/scraping/feed/" />
# <link rel="alternate" type="application/rss+xml" title="スクレイピング演習用デモサイト &raquo; コメントフィード" href="https://www.jashin.info/ki
